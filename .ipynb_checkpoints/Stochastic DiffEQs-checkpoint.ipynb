# %% [markdown]
# # Stchastic Differential Equation solver and visualization

# %%
using Plots, DifferentialEquations
# Out:
# ┌ Info: Precompiling DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa]
# └ @ Base loading.jl:1186

# %% [markdown]
# ## Solve Black-shoels model (Financial mathematics)

# %%
α=1
β=1
u₀=1/2
f(u,p,t) = α*u
g(u,p,t) = β*u
dt = 1//2^(4)
tspan = (0.0,1.0)
prob = SDEProblem(f,g,u₀,(0.0,1.0))
# Out:
# SDEProblem with uType Float64 and tType Float64. In-place: false
# timespan: (0.0, 1.0)
# u0: 0.5

# %%
sol_EM = solve(prob, EM(), dt=dt)
a = plot(sol_EM)
for i in 1:10
    sol_EM = solve(prob, EM(), dt=dt)
    a = plot!(sol_EM)
end

# %%
a

# %%
sol_SRIW = solve(prob, SRIW1(), dt=dt)
plot(sol_SRIW)
